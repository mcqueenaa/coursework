# %%
import pymorphy2 as pm2 
pmm = pm2.MorphAnalyzer() 
import re
from collections import Counter, defaultdict

# %%
import nltk 
from nltk import ngrams
from nltk.text import Text 
nltk.download("stopwords") 
#--------# 
from nltk.corpus import stopwords 

#Create lemmatizer and stopwords list 
russian_stopwords = stopwords.words("russian")
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\Sony\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
def open_text(name):
    with open(name, 'r', encoding='utf-8') as n:
        text = n.read()
    return text

# %%
def clean_text(text):
    text = re.sub(r'[^\w\s]','',text) 
    text = re.sub(r'\d', '', text) 
    text = re.sub(r'[A-Za-z]', '', text) 
    text = [pmm.normal_forms(x)[0] for x in text.split() if x not in russian_stopwords] 
    return text

# %%
text = clean_text(open_text('geometry.txt'))

# %%
text
# Out:
# ['прямоугольный',
#  'треугольник',
#  'треугольник',
#  'называться',
#  'прямоугольный',
#  'прямая',
#  'угол',
#  'треугольник',
#  'называться',
#  'остроугольный',
#  'угол',
#  'острый',
#  'тупоугольный',
#  'тупой',
#  'угол',
#  'так',
#  'сумма',
#  'угол',
#  'треугольник',
#  'равный',
#  'сто',
#  'восемьдесят',
#  'градус',
#  'прямоугольный',
#  'треугольник',
#  'прямая',
#  'угол',
#  'другой',
#  'угол',
#  'прямоугольный',
#  'треугольник',
#  'острый',
#  'сумма',
#  'острый',
#  'угол',
#  'прямоугольный',
#  'треугольник',
#  'равный',
#  'сто',
#  'восемьдесят',
#  'градус',
#  'минус',
#  'девяносто',
#  'градус',
#  'равно',
#  'девяносто',
#  'градус',
#  'сторона',
#  'прямоугольный',
#  'треугольник',
#  'противолежащий',
#  'прямой',
#  'угол',
#  'называться',
#  'гипотенуза',
#  'два',
#  'другой',
#  'сторона',
#  'называться',
#  'катет',
#  'косинус',
#  'угол',
#  'косинус',
#  'угол',
#  'прямоугольный',
#  'треугольник',
#  'называться',
#  'отношение',
#  'прилежащий',
#  'катет',
#  'гипотенуза',
#  'косинус',
#  'угол',
#  'альфа',
#  'обозначаться',
#  'кос',
#  'альфа',
#  'α',
#  'рассмотреть',
#  'треугольник',
#  'а',
#  'б',
#  'ц',
#  'прямая',
#  'угол',
#  'ц',
#  'обозначить',
#  'угол',
#  'вершина',
#  'а',
#  'альфа',
#  'косинус',
#  'угол',
#  'альфа',
#  'равный',
#  'отношение',
#  'катет',
#  'а',
#  'ц',
#  'прилежащий',
#  'это',
#  'угол',
#  'гипотенуза',
#  'а',
#  'б',
#  'косинус',
#  'альфа',
#  'равный',
#  'отношение',
#  'а',
#  'ц',
#  'а',
#  'б',
#  'теорема',
#  'косинус',
#  'угол',
#  'зависеть',
#  'градусный',
#  'мера',
#  'угол',
#  'зависеть',
#  'расположение',
#  'размер',
#  'треугольник',
#  'это',
#  'обозначать',
#  'два',
#  'прямоугольный',
#  'треугольник',
#  'один',
#  'острый',
#  'угол',
#  'косинус',
#  'угол',
#  'равный',
#  'доказательство',
#  'пусть',
#  'а',
#  'б',
#  'ц',
#  'а',
#  'штрих',
#  'б',
#  'штрих',
#  'ц',
#  'штрих',
#  'прямоугольный',
#  'треугольник',
#  'один',
#  'угол',
#  'вершина',
#  'а',
#  'а',
#  'штрих',
#  'равный',
#  'альфа',
#  'требоваться',
#  'доказать',
#  'отношение',
#  'а',
#  'штрих',
#  'ц',
#  'штрих',
#  'а',
#  'штрих',
#  'б',
#  'штрих',
#  'равно',
#  'отношение',
#  'а',
#  'ц',
#  'а',
#  'б',
#  'построить',
#  'треугольник',
#  'а',
#  'б',
#  'ц',
#  'равный',
#  'треугольник',
#  'а',
#  'штрих',
#  'б',
#  'штрих',
#  'ц',
#  'штрих',
#  'так',
#  'прямая',
#  'б',
#  'ц',
#  'б',
#  'ц',
#  'перпендикулярный',
#  'прямая',
#  'а',
#  'ц',
#  'параллельный',
#  'по',
#  'теорема',
#  'пропорциональный',
#  'отрезка',
#  'а',
#  'ц',
#  'относиться',
#  'а',
#  'б',
#  'а',
#  'ц',
#  'относиться',
#  'а',
#  'б',
#  'а',
#  'построение',
#  'а',
#  'ц',
#  'равно',
#  'а',
#  'штрих',
#  'ц',
#  'штрих',
#  'а',
#  'б',
#  'равно',
#  'а',
#  'штрих',
#  'б',
#  'штрих',
#  'отношение',
#  'а',
#  'штрих',
#  'ц',
#  'штрих',
#  'а',
#  'штрих',
#  'б',
#  'штрих',
#  'равно',
#  'отношение',
#  'а',
#  'ц',
#  'а',
#  'б',
#  'теорема',
#  'доказать',
#  'теорема',
#  'пифагор',
#  'в',
#  'прямоугольный',
#  'треугольник',
#  'квадрат',
#  'гипотенуза',
#  'равный',
#  'сумма',
#  'квадрат',
#  'катет',
#  'доказательство',
#  'пусть',
#  'а',
#  'б',
#  'ц',
#  'данный',
#  'прямоугольный',
#  'треугольник',
#  'прямая',
#  'угол',
#  'ц',
#  'провести',
#  'высота',
#  'ц',
#  'далее',
#  'вершина',
#  'угол',
#  'ц',
#  'определение',
#  'косинус',
#  'угол',
#  'косинус',
#  'а',
#  'равный',
#  'отношение',
#  'а',
#  'далее',
#  'а',
#  'ц',
#  'отношение',
#  'а',
#  'ц',
#  'а',
#  'б',
#  'отсюда',
#  'равенство',
#  'произведение',
#  'а',
#  'б',
#  'а',
#  'далее',
#  'равно',
#  'а',
#  'ц',
#  'квадрат',
#  'аналогично',
#  'косинус',
#  'угол',
#  'б',
#  'равный',
#  'отношение',
#  'б',
#  'далее',
#  'б',
#  'ц',
#  'равный',
#  'отношение',
#  'б',
#  'ц',
#  'а',
#  'б',
#  'отсюда',
#  'произведение',
#  'а',
#  'б',
#  'б',
#  'далее',
#  'равно',
#  'б',
#  'ц',
#  'квадрат',
#  'складывать',
#  'получить',
#  'равенство',
#  'почленно',
#  'замечать',
#  'сумма',
#  'а',
#  'далее',
#  'далее',
#  'б',
#  'равный',
#  'а',
#  'б',
#  'получать',
#  'а',
#  'ц',
#  'квадрат',
#  'плюс',
#  'б',
#  'ц',
#  'квадрат',
#  'равно',
#  'произведение',
#  'а',
#  'б',
#  'сумма',
#  'а',
#  'далее',
#  'далее',
#  'б',
#  'очередь',
#  'равно',
#  'а',
#  'б',
#  'квадрат',
#  'теорема',
#  'доказать',
#  'из',
#  'теорема',
#  'пифагор',
#  'следовать',
#  'прямоугольный',
#  'треугольник',
#  'люба',
#  'катет',
#  'маленький',
#  'гипотенуза',
#  'отсюда',
#  'очередь',
#  'следовать',
#  'косинус',
#  'любой',
#  'острый',
#  'угол',
#  'альфа',
#  'маленький',
#  'единица',
#  'равнобедренный',
#  'треугольник',
#  'треугольник',
#  'называться',
#  'равнобедренный',
#  'сторона',
#  'равный',
#  'этот',
#  'равный',
#  'сторона',
#  'называться',
#  'боков',
#  'сторона',
#  'три',
#  'сторона',
#  'называться',
#  'основание',
#  'треугольник',
#  'доказать',
#  'свойство',
#  'угол',
#  'равнобедренный',
#  'треугольник',
#  'теорема',
#  'в',
#  'равнобедренный',
#  'треугольник',
#  'угол',
#  'основание',
#  'равный',
#  'доказательство',
#  'пусть',
#  'б',
#  'ц',
#  'равнобедренный',
#  'треугольник',
#  'основание',
#  'б',
#  'боков',
#  'сторона',
#  'ц',
#  'равно',
#  'ц',
#  'б',
#  'треугольник',
#  'ц',
#  'б',
#  'равный',
#  'треугольник',
#  'ц',
#  'б',
#  'первое',
#  'признак',
#  'равенство',
#  'треугольник',
#  'действительно',
#  'сторона',
#  'ц',
#  'равный',
#  'сторона',
#  'ц',
#  'б',
#  'сторона',
#  'ц',
#  'б',
#  'равный',
#  'сторона',
#  'ц',
#  'угол',
#  'ц',
#  'равный',
#  'угол',
#  'ц',
#  'из',
#  'равенство',
#  'треугольник',
#  'следовать',
#  'угол',
#  'равный',
#  'угол',
#  'б',
#  'теорема',
#  'доказать',
#  'обратный',
#  'теорема',
#  'если',
#  'треугольник',
#  'угол',
#  'равный',
#  'равнобедренный',
#  'доказательство',
#  'пусть',
#  'треугольник',
#  'б',
#  'ц',
#  'который',
#  'угол',
#  'равный',
#  'угол',
#  'б',
#  'доказать',
#  'равнобедренный',
#  'основание',
#  'б',
#  'треугольник',
#  'б',
#  'ц',
#  'равный',
#  'треугольник',
#  'б',
#  'ц',
#  'второе',
#  'признак',
#  'равенство',
#  'треугольник',
#  'действительно',
#  'сторона',
#  'б',
#  'равный',
#  'сторона',
#  'б',
#  'угол',
#  'б',
#  'равный',
#  'угол',
#  'угол',
#  'равный',
#  'угол',
#  'б',
#  'равенство',
#  'треугольник',
#  'следовать',
#  'ц',
#  'равно',
#  'б',
#  'ц',
#  'значит',
#  'определение',
#  'треугольник',
#  'б',
#  'ц',
#  'равнобедренный',
#  'теорема',
#  'доказать',
#  'соотношение',
#  'сторона',
#  'угол',
#  'прямоугольный',
#  'треугольник',
#  'пусть',
#  'б',
#  'ц',
#  'прямоугольный',
#  'треугольник',
#  'прямая',
#  'угол',
#  'ц',
#  'острый',
#  'угол',
#  'вершина',
#  'равный',
#  'альфа',
#  'согласно',
#  'определение',
#  'косинус',
#  'альфа',
#  'равный',
#  'отношение',
#  'катет',
#  'прилежащий',
#  'угол',
#  'альфа',
#  'гипотенуза',
#  'косинус',
#  'альфа',
#  'равный',
#  'ц',
#  'делить',
#  'б',
#  'синус',
#  'угол',
#  'альфа',
#  'называться',
#  'отношение',
#  'противолежащий',
#  'катет',
#  'б',
#  'ц',
#  'гипотенуза',
#  'б',
#  'синус',
#  'альфа',
#  'равно',
#  'делить',
#  'б',
#  'тангенс',
#  'угол',
#  'альфа',
#  'называться',
#  'отношение',
#  'противолежащий',
#  'катет',
#  'б',
#  'ц',
#  'прилежащий',
#  'катет',
#  'ц',
#  'тангенс',
#  'альфа',
#  'равный',
#  'б',
#  'ц',
#  'делить',
#  'ц',
#  'котангенс',
#  'угол',
#  'альфа',
#  'называться',
#  'отношение',
#  'прилежащий',
#  'катет',
#  'ц',
#  'противолежащий',
#  'катет',
#  'б',
#  'ц',
#  'котангенс',
#  'альфа',
#  'равный',
#  'ц',
#  'делить',
#  'б',
#  'ц',
#  'синус',
#  'тангенс',
#  'котангенс',
#  'угол',
#  'косинус',
#  'зависеть',
#  'величина',
#  'угол',
#  'действительно',
#  'теорема',
#  'пифагор',
#  'б',
#  'ц',
#  'равный',
#  'корень',
#  'квадратный',
#  'разность',
#  'б',
#  'квадрат',
#  'ц',
#  'квадрат',
#  'по',
#  'определение',
#  'синус',
#  'альфа',
#  'это',
#  'б',
#  'ц',
#  'делить',
#  'б',
#  'значит',
#  'синус',
#  'альфа',
#  'равный',
#  'отношение',
#  'корень',
#  'квадратный',
#  'разность',
#  'б',
#  'квадрат',
#  'минус',
#  'ц',
#  'квадрат',
#  'б',
#  'что',
#  'очерёд',
#  'равно',
#  'корень',
#  'квадратный',
#  'разность',
#  'единица',
#  'квадрат',
#  'отношение',
#  'ц',
#  'б',
#  'равно',
#  'корень',
#  'квадратный',
#  'разность',
#  'единица',
#  'косинус',
#  'квадрат',
#  'альфа',
#  'так',
#  'косинус',
#  'альфа',
#  'зависеть',
#  'величина',
#  'угол',
#  'синус',
#  'альфа',
#  'зависеть',
#  'величина',
#  'угол',
#  'по',
#  'определение',
#  'тангенс',
#  'альфа',
#  'равный',
#  'отношение',
#  'б',
#  'ц',
#  'ц',
#  'котангенс',
#  'альфа',
#  'равный',
#  'отношение',
#  'ц',
#  'б',
#  'ц',
#  'разделить',
#  'числитель',
#  'знаменатель',
#  'каждый',
#  'дробь',
#  'б',
#  'тангенс',
#  'альфа',
#  'равный',
#  'отношение',
#  'б',
#  'ц',
#  'б',
#  'делить',
#  'отношение',
#  'ц',
#  'б',
#  'очередь',
#  'равно',
#  'отношение',
#  'синус',
#  'альфа',
#  'косинус',
#  'альфа',
#  'котангенс',
#  'альфа',
#  'равный',
#  'отношение',
#  'ц',
#  'б',
#  'делить',
#  'отношение',
#  'б',
#  'ц',
#  'б',
#  'очередь',
#  'равно',
#  'отношение',
#  'косинус',
#  'альфа',
#  'синус',
#  'альфа',
#  'значит',
#  'тангенс',
#  'альфа',
#  'котангенс',
#  'альфа',
#  'зависеть',
#  'величина',
#  'угол',
#  'из',
#  'определение',
#  'синус',
#  'альфа',
#  'косинус',
#  'альфа',
#  'тангенс',
#  'альфа',
#  'котангенс',
#  'альфа',
#  'получать',
#  'следующий',
#  'правило',
#  'первое',
#  'катет',
#  'противолежащий',
#  'угол',
#  'альфа',
#  'равный',
#  'произведение',
#  'гипотенуза',
#  'синус',
#  'альфа',
#  'два',
#  'катет',
#  'прилежащий',
#  'угол',
#  'альфа',
#  'равный',
#  'произведение',
#  'гипотенуза',
#  'косинус',
#  'альфа',
#  'третье',
#  'катет',
#  'противолежащий',
#  'угол',
#  'альфа',
#  'равный',
#  'произведение',
#  'два',
#  'катет',
#  'тангенс',
#  'альфа',
#  'и',
#  'четыре',
#  'катет',
#  'прилежащий',
#  'угол',
#  'альфа',
#  'равный',
#  'произведение',
#  'два',
#  'катет',
#  'котангенс',
#  'альфа',
#  'основной',
#  'тригонометрический',
#  'тождество',
#  'мы',
#  'знать',
#  'тангенс',
#  'альфа',
#  'равный',
#  'синус',
#  'альфа',
#  'делить',
#  'косинус',
#  'альфа',
#  'котангенс',
#  'альфа',
#  'равный',
#  'косинус',
#  'альфа',
#  'делить',
#  'синус',
#  'альфа',
#  'доказать',
#  'следующий',
#  'тождество',
#  'синус',
#  'квадрат',
#  'альфа',
#  'плюс',
#  'косинус',
#  'квадрат',
#  'альфа',
#  'равно',
#  'единица',
#  'единица',
#  'плюс',
#  'тангенс',
#  'квадрат',
#  'альфа',
#  'равный',
#  'единица',
#  'делить',
#  'косинус',
#  'квадрат',
#  'альфа',
#  'и',
#  'единица',
#  'плюс',
#  'котангенс',
#  'квадрат',
#  'альфа',
#  'равный',
#  'единица',
#  'делить',
#  'синус',
#  'квадрат',
#  'альфа',
#  'взять',
#  'люба',
#  'прямоугольный',
#  'треугольник',
#  'б',
#  'ц',
#  'угол',
#  'вершина',
#  'равный',
#  'альфа',
#  'по',
#  'теорема',
#  'пифагор',
#  'б',
#  'ц',
#  'квадрат',
#  'плюс',
#  'ц',
#  'квадрат',
#  'равно',
#  'б',
#  'квадрат',
#  'разделить',
#  'оба',
#  'часть',
#  'равенство',
#  'б',
#  'квадрат',
#  'получить',
#  'квадрат',
#  'отношение',
#  'б',
#  'ц',
#  'б',
#  'плюс',
#  'квадрат',
#  'отношение',
#  'ц',
#  'б',
#  'равный',
#  'единица',
#  'но',
#  'б',
#  'ц',
#  'делить',
#  'б',
#  'это',
#  'синус',
#  'альфа',
#  'а',
#  'ц',
#  'делить',
#  'б',
#  'это',
#  'косинус',
#  'альфа',
#  'такой',
#  'образ',
#  'синус',
#  'квадрат',
#  'альфа',
#  'плюс',
#  'косинус',
#  'квадрат',
#  'альфа',
#  'равный',
#  'единица',
#  'это',
#  'равенство',
#  'называться',
#  'основный',
#  'тригонометрический',
#  'тождество',
#  'оно',
#  'верно',
#  'любой',
#  'острый',
#  'угол',
#  'альфа',
#  'чтобы',
#  'получить',
#  'два',
#  'тождество',
#  'разделить',
#  'оба',
#  'часть',
#  'получить',
#  'тождество',
#  'косинус',
#  'квадрат',
#  'альфа',
#  'синус',
#  'квадрат',
#  'альфа',
#  'делить',
#  'косинус',
#  'квадрат',
#  'альфа',
#  'плюс',
#  'косинус',
#  'квадрат',
#  'альфа',
#  'делить',
#  'косинус',
#  'квадрат',
#  'альфа',
#  'равно',
#  'единица',
#  'делить',
#  'косинус',
#  'квадрат',
#  'альфа',
#  'тангенс',
#  'квадрат',
#  'альфа',
#  'плюс',
#  'единица',
#  'равный',
#  'единица',
#  'делить',
#  'косинус',
#  'квадрат',
#  'альфа',
#  'если',
#  'оба',
#  'часть',
#  'тождество',
#  'синус',
#  'квадрат',
#  'альфа',
#  'плюс',
#  'косинус',
#  ...]

# %%
len(text)
# Out:
# 1650

# %%
def ngrammer(tokens, n):
    ngrams = []
    if n>1:
        for i in range(len(text) - (n - 1)):
            ngrams.append(tuple(text[i:i+n]))
    
    return ngrams

# %%
trigram = ngrammer(text, 3)

# %%
type(trigram[0])
# Out:
# tuple

# %%
trigram[:10]
# Out:
# [('прямоугольный', 'треугольник', 'треугольник'),
#  ('треугольник', 'треугольник', 'называться'),
#  ('треугольник', 'называться', 'прямоугольный'),
#  ('называться', 'прямоугольный', 'прямая'),
#  ('прямоугольный', 'прямая', 'угол'),
#  ('прямая', 'угол', 'треугольник'),
#  ('угол', 'треугольник', 'называться'),
#  ('треугольник', 'называться', 'остроугольный'),
#  ('называться', 'остроугольный', 'угол'),
#  ('остроугольный', 'угол', 'острый')]

# %%
word_counter = Counter()

word_counter.update(ngrammer(text, 3))

# %%
word_counter.most_common(40)
# Out:
# [(('косинус', 'квадрат', 'альфа'), 11),
#  (('альфа', 'равный', 'отношение'), 8),
#  (('синус', 'квадрат', 'альфа'), 7),
#  (('два', 'параллельный', 'прямая'), 7),
#  (('накрест', 'лежать', 'угол'), 6),
#  (('угол', 'альфа', 'равный'), 5),
#  (('ц', 'а', 'б'), 5),
#  (('а', 'штрих', 'б'), 5),
#  (('штрих', 'б', 'штрих'), 5),
#  (('штрих', 'ц', 'штрих'), 5),
#  (('отношение', 'б', 'ц'), 5),
#  (('угол', 'равный', 'угол'), 5),
#  (('треугольник', 'б', 'ц'), 5),
#  (('ц', 'делить', 'б'), 5),
#  (('отношение', 'ц', 'б'), 5),
#  (('квадрат', 'альфа', 'плюс'), 5),
#  (('делить', 'косинус', 'квадрат'), 5),
#  (('лежать', 'угол', 'равный'), 5),
#  (('угол', 'прямоугольный', 'треугольник'), 4),
#  (('а', 'б', 'ц'), 4),
#  (('отношение', 'а', 'ц'), 4),
#  (('а', 'ц', 'а'), 4),
#  (('б', 'ц', 'равный'), 4),
#  (('б', 'ц', 'б'), 4),
#  (('равный', 'отношение', 'б'), 4),
#  (('тангенс', 'альфа', 'равный'), 4),
#  (('котангенс', 'альфа', 'равный'), 4),
#  (('зависеть', 'величина', 'угол'), 4),
#  (('корень', 'квадратный', 'разность'), 4),
#  (('альфа', 'котангенс', 'альфа'), 4),
#  (('альфа', 'равный', 'произведение'), 4),
#  (('альфа', 'плюс', 'косинус'), 4),
#  (('плюс', 'косинус', 'квадрат'), 4),
#  (('квадрат', 'альфа', 'равно'), 4),
#  (('альфа', 'равно', 'единица'), 4),
#  (('параллельный', 'прямая', 'секущая'), 4),
#  (('параллельный', 'прямая', 'пересечь'), 4),
#  (('прямая', 'пересечь', 'секущая'), 4),
#  (('прямоугольный', 'треугольник', 'прямая'), 3),
#  (('треугольник', 'прямая', 'угол'), 3)]

# %%
##надо добавить стоп-слова
